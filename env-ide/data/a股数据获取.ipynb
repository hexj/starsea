# %%
import tushare as ts
import pandas
import datetime

# Step 1. Get tickers online
tickers = ts.get_index()
print(type(tickers))
print(len(tickers))
print(tickers)
# Step 2. Save the ticker list to a local file
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 26
#       code    name  change        open    preclose       close        high  \
# 0   000001    上证指数   -1.41   2861.3323   2908.7660   2867.8376   2872.4730
# 1   000002    Ａ股指数   -1.41   2997.1574   3046.9106   3004.0201   3008.8872
# 2   000003    Ｂ股指数   -1.18    275.3937    277.5925    274.3258    275.9442
# 3   000008    综合指数   -1.52   2807.9260   2850.7458   2807.5159   2815.0689
# 4   000009   上证380   -1.10   4454.2218   4532.7560   4482.7994   4485.9053
# 5   000010   上证180   -1.45   8277.1200   8420.4494   8298.4061   8317.5477
# 6   000011    基金指数   -0.90   6110.1396   6157.8204   6102.2349   6110.1396
# 7   000012    国债指数    0.03    174.0861    174.0629    174.1067    174.1078
# 8   000016    上证50   -1.53   2837.3685   2887.8665   2843.7704   2852.1151
# 9   000017     新综指   -1.41   2416.6061   2456.7206   2422.1368   2426.0622
# 10  000300   沪深300   -1.47   3729.1309   3803.4694   3747.4379   3754.5326
# ...
